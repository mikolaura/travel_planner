# %%
# !pip install requests

# %%
import requests

r = requests.get("https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/Lviv,Ukraine/2025-08-15/2025-08-17?unitGroup=metric&key=HQQCMSCCPX6XQXCPX9QNLLL8H&contentType=json")

# %%
from json import load

r.json()['days'][0]
# Out:
# {'datetime': '2025-08-15',
#  'datetimeEpoch': 1755205200,
#  'tempmax': 29.8,
#  'tempmin': 16.6,
#  'temp': 23.3,
#  'feelslikemax': 28.9,
#  'feelslikemin': 16.6,
#  'feelslike': 23.1,
#  'dew': 13.5,
#  'humidity': 56.9,
#  'precip': 0.0,
#  'precipprob': 0.0,
#  'precipcover': 0.0,
#  'preciptype': None,
#  'snow': 0.0,
#  'snowdepth': 0.0,
#  'windgust': 24.1,
#  'windspeed': 8.6,
#  'winddir': 83.7,
#  'pressure': 1021.3,
#  'cloudcover': 18.1,
#  'visibility': 24.1,
#  'solarradiation': 272.7,
#  'solarenergy': 23.7,
#  'uvindex': 8.0,
#  'severerisk': 10.0,
#  'sunrise': '06:14:08',
#  'sunriseEpoch': 1755227648,
#  'sunset': '20:41:43',
#  'sunsetEpoch': 1755279703,
#  'moonphase': 0.72,
#  'conditions': 'Clear',
#  'description': 'Clear conditions throughout the day.',
#  'icon': 'clear-day',
#  'stations': None,
#  'source': 'fcst',
#  'hours': [{'datetime': '00:00:00',
#    'datetimeEpoch': 1755205200,
#    'temp': 20.8,
#    'feelslike': 20.8,
#    'humidity': 63.4,
# ...
